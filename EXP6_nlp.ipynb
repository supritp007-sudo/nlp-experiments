# %% [markdown]
# <a href="https://colab.research.google.com/github/supritp007-sudo/nlp-experiments/blob/main/Copy_of_NLP_EXP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
text="Today is Sunday and   i'am practicing Python "

# %%
print(text)
# Out:
# Today is Sunday and   i'am practicing Python

# %%
nltk.download('punkt_tab')
token=word_tokenize(text)
print("Tokenization: \n")
print(token)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# Tokenization:
#
# ['Today', 'is', 'Sunday', 'and', "i'am", 'practicing', 'Python']
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in token if word.lower() not in stop_words]
print("Stop-word Removal:")
print(filtered_tokens)
print("\n")
# Out:
# Stop-word Removal:
# ['Today', 'Sunday', "i'am", 'practicing', 'Python']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(" Lemmatization:")
print(lemmatized_words)
print("\n")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#  Lemmatization:
# ['Today', 'Sunday', "i'am", 'practicing', 'Python']

# %%
nltk.download('averaged_perceptron_tagger_eng') # Download the specific English tagger
pos_tags = pos_tag(token)
print(" Part-of-Speech Tagging:")
print(pos_tags)
print("\n")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
#  Part-of-Speech Tagging:
# [('Today', 'NN'), ('is', 'VBZ'), ('Sunday', 'NNP'), ('and', 'CC'), ("i'am", 'VB'), ('practicing', 'VBG'), ('Python', 'NNP')]

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words') # Add this line to download the 'words' corpus
from nltk.chunk import ne_chunk
ner_tree = ne_chunk(pos_tags)
print("6. Named Entity Recognition:")
print(ner_tree)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# 6. Named Entity Recognition:
# (S
#   Today/NN
#   is/VBZ
#   Sunday/NNP
#   and/CC
#   i'am/VB
#   practicing/VBG
#   (PERSON Python/NNP))
