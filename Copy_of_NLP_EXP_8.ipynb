# %% [markdown]
# <a href="https://colab.research.google.com/github/supritp007-sudo/nlp-experiments/blob/main/Copy_of_NLP_EXP_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pandas as pd
from collections import Counter

documents = [
    "I love machine learning",
    "Machine learning is powerful",
    "I love AI"
]

processed_docs = [doc.lower().split() for doc in documents]
N = len(processed_docs)

vocab = sorted(set(word for doc in processed_docs for word in doc))
idf = {}
for word in vocab:
    df = sum(1 for doc in processed_docs if word in doc)
    idf[word] = math.log(N / df)

tfidf_matrix = []

for doc in processed_docs:
    tfidf_row = []
    word_freq = Counter(doc)
    total_words = len(doc)


    for word in vocab:
        tf = word_freq[word] / total_words
        tfidf = tf * idf[word]
        tfidf_row.append(round(tfidf, 4))

    tfidf_matrix.append(tfidf_row)

tfidf_df = pd.DataFrame(tfidf_matrix, columns=vocab)
tfidf_df.index = [f"Doc{i+1}" for i in range(N)]

print(tfidf_df)
# Out:
#           ai       i      is  learning    love  machine  powerful
# Doc1  0.0000  0.1014  0.0000    0.1014  0.1014   0.1014    0.0000
# Doc2  0.0000  0.0000  0.2747    0.1014  0.0000   0.1014    0.2747
# Doc3  0.3662  0.1352  0.0000    0.0000  0.1352   0.0000    0.0000
